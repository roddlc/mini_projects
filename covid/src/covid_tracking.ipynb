# %% [markdown]
# # Script to consolidate data from the [Covid Tracking Project](https://covidtracking.com/) and calculate simple ratios for display in Tableau

# %% [markdown]
# # Packages and data import

# %%
# packages
import requests, json
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# should we plot anything in this notebook, this will allow visual to display
# %matplotlib inline

# show all columns
pd.set_option('display.max_columns', None)

# %%
# table with state names and abbreviations
states_abbr = pd.read_csv("../inputs/state_table.csv")
states_abbr.head()
# Out:
#         state state_abbr
# 0     Alabama         AL
# 1      Alaska         AK
# 2     Arizona         AZ
# 3    Arkansas         AR
# 4  California         CA

# %% [markdown]
# ### Load [US daily 4pm EST](https://covidtracking.com/data/us-daily) data

# %%
national_url = "https://covidtracking.com/api/us/daily"

# %%
# request from url
national_raw = requests.get(national_url)

# %%
# convert request to json
national_json = national_raw.json()

# %%
# show first record in json file
national_json[:1]
# Out:
# [{'date': 20200416,
#   'states': 56,
#   'positive': 663260,
#   'negative': 2737804,
#   'pending': 16927,
#   'hospitalizedCurrently': 57494,
#   'hospitalizedCumulative': 74705,
#   'inIcuCurrently': 15150,
#   'inIcuCumulative': 1834,
#   'onVentilatorCurrently': 5940,
#   'onVentilatorCumulative': 137,
#   'recovered': 42032,
#   'hash': 'e42dcecd56cc690f4b4c5c242e02b8eb8e3491b6',
#   'dateChecked': '2020-04-16T20:00:00Z',
#   'death': 30296,
#   'hospitalized': 74705,
#   'total': 3417991,
#   'totalTestResults': 3401064,
#   'posNeg': 3401064,
#   'deathIncrease': 2136,
#   'hospitalizedIncrease': 5102,
#   'negativeIncrease': 127705,
#   'positiveIncrease': 30604,
#   'totalTestResultsIncrease': 158309}]

# %%
# convert json to dataframe
national = pd.DataFrame(national_json)

# show first five rows
national.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200416      56    663260  2737804.0  16927.0                57494.0
# 1  20200415      56    632656  2610099.0  16901.0                58361.0
# 2  20200414      56    602473  2479147.0  16615.0                54215.0
# 3  20200413      56    576774  2358232.0  17159.0                50968.0
# 4  20200412      56    551826  2254066.0  16419.0                51413.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 74705.0         15150.0           1834.0
# 1                 69603.0         14667.0           1783.0
# 2                 67547.0         14039.0           1715.0
# 3                 62673.0         13632.0           1628.0
# 4                 61201.0         13917.0           1455.0
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                 5940.0                   137.0    42032.0
# 1                 6032.0                   223.0    39405.0
# 2                 5975.0                   221.0    37645.0
# 3                 6168.0                   210.0    35442.0
# 4                 5986.0                   160.0    34151.0
#
#                                        hash           dateChecked  death  \
# 0  e42dcecd56cc690f4b4c5c242e02b8eb8e3491b6  2020-04-16T20:00:00Z  30296
# 1  ca6d549a02f56add12897c5a47d051c50f2e8c75  2020-04-15T20:00:00Z  28160
# 2  7ea156ba5cb34498d2798ce71d9470bdbb27201b  2020-04-14T20:00:00Z  25668
# 3  171a7aa78e00daf2ddb2e32baedcdf1127162a17  2020-04-13T20:00:00Z  23369
# 4  b66df37c6be1e91d8fb155d5612a9fb3202e8e52  2020-04-12T20:00:00Z  21919
#
#    hospitalized    total  totalTestResults   posNeg  deathIncrease  \
# 0       74705.0  3417991           3401064  3401064         2136.0
# 1       69603.0  3259656           3242755  3242755         2492.0
# 2       67547.0  3098235           3081620  3081620         2299.0
# 3       62673.0  2952165           2935006  2935006         1450.0
# 4       61201.0  2822311           2805892  2805892         1564.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                5102.0          127705.0           30604.0
# 1                2056.0          130952.0           30183.0
# 2                4874.0          120915.0           25699.0
# 3                1472.0          104166.0           24948.0
# 4                2652.0          111243.0           28983.0
#
#    totalTestResultsIncrease
# 0                  158309.0
# 1                  161135.0
# 2                  146614.0
# 3                  129114.0
# 4                  140226.0

# %% [markdown]
# ### Load [states daily 4pm EST](https://docs.google.com/spreadsheets/u/2/d/e/2PACX-1vRwAqp96T9sYYq2-i7Tj0pvTf6XVHjDSMIKBdZHXiCGGdNC0ypEU9NbngS8mxea55JuCFuua1MUeOj5/pubhtml) data

# %%
states_url = "https://covidtracking.com/api/states/daily"

# %%
# request from url
states_raw = requests.get(states_url)

# %%
# convert request to json
states_json = states_raw.json()

# %%
# show first record in json file
states_json[:1]
# Out:
# [{'date': 20200416,
#   'state': 'AK',
#   'positive': 300,
#   'negative': 8435,
#   'pending': None,
#   'hospitalizedCurrently': None,
#   'hospitalizedCumulative': 35,
#   'inIcuCurrently': None,
#   'inIcuCumulative': None,
#   'onVentilatorCurrently': None,
#   'onVentilatorCumulative': None,
#   'recovered': 110,
#   'hash': '42353f78693987154276c7c482342a46ec11c180',
#   'dateChecked': '2020-04-16T20:00:00Z',
#   'death': 9,
#   'hospitalized': 35,
#   'total': 8735,
#   'totalTestResults': 8735,
#   'posNeg': 8735,
#   'fips': '02',
#   'deathIncrease': 0,
#   'hospitalizedIncrease': 1,
#   'negativeIncrease': 64,
#   'positiveIncrease': 7,
#   'totalTestResultsIncrease': 71}]

# %%
# convert json to dataframe
states = pd.DataFrame(states_json)

# show first five rows
states.head()
# Out:
#        date state  positive  negative  pending  hospitalizedCurrently  \
# 0  20200416    AK     300.0    8435.0      NaN                    NaN
# 1  20200416    AL    4345.0   32046.0      NaN                    NaN
# 2  20200416    AR    1620.0   21055.0      NaN                   85.0
# 3  20200416    AS       0.0       3.0     17.0                    NaN
# 4  20200416    AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash           dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180  2020-04-16T20:00:00Z    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f  2020-04-16T20:00:00Z  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e  2020-04-16T20:00:00Z   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c  2020-04-16T20:00:00Z    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a  2020-04-16T20:00:00Z  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease
# 0                      71.0
# 1                    2314.0
# 2                     841.0
# 3                       0.0
# 4                    2088.0

# %%
# data types by column
states.dtypes
# Out:
# date                          int64
# state                        object
# positive                    float64
# negative                    float64
# pending                     float64
# hospitalizedCurrently       float64
# hospitalizedCumulative      float64
# inIcuCurrently              float64
# inIcuCumulative             float64
# onVentilatorCurrently       float64
# onVentilatorCumulative      float64
# recovered                   float64
# hash                         object
# dateChecked                  object
# death                       float64
# hospitalized                float64
# total                       float64
# totalTestResults            float64
# posNeg                      float64
# fips                         object
# deathIncrease               float64
# hospitalizedIncrease        float64
# negativeIncrease            float64
# positiveIncrease            float64
# totalTestResultsIncrease    float64
# dtype: object

# %%
# set 'date' to date and 'dateChecked' to timestamp
states['date'] = pd.to_datetime(states['date'], format = "%Y%m%d").dt.strftime('%Y-%m-%d')
states['dateChecked'] = pd.to_datetime(states['dateChecked'])

# rename 'state' to 'state_abbr'
states.rename(columns = {'state': 'state_abbr'}, inplace = True)

# show first five rows
states.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease
# 0                      71.0
# 1                    2314.0
# 2                     841.0
# 3                       0.0
# 4                    2088.0

# %% [markdown]
# ### Load state populations from Census American Community Survey (ACS5)

# %%
# map url to var
states_acs5_url = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_001E&for=state:*"

# %%
# import data from url
states_acs5_raw = requests.get(states_acs5_url)

# %%
# data to json
states_acs5_json = states_acs5_raw.json()

# %%
# json to dataframe
states_pop = pd.DataFrame(states_acs5_json[1:], columns = states_acs5_json[0]).rename(columns = 
                                                        {"B01001_001E": "population",
                                                         "NAME": "state",
                                                         "state": "state_fips"})
# show first five rows
states_pop.head()
# Out:
#          state population state_fips
# 0  Puerto Rico    3468963         72
# 1      Alabama    4850771         01
# 2       Alaska     738565         02
# 3      Arizona    6809946         04
# 4     Arkansas    2977944         05

# %% [markdown]
# Making an additional join so we have state abbreviation - will be needed for join below

# %%
# left join state abbr
states_pop = pd.merge(states_pop, states_abbr, on = "state", how = "left")

# rename 'state' to 'state_name'

# show first five rows
states_pop.head()
# Out:
#          state population state_fips state_abbr
# 0  Puerto Rico    3468963         72         PR
# 1      Alabama    4850771         01         AL
# 2       Alaska     738565         02         AK
# 3      Arizona    6809946         04         AZ
# 4     Arkansas    2977944         05         AR

# %%
states.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease
# 0                      71.0
# 1                    2314.0
# 2                     841.0
# 3                       0.0
# 4                    2088.0

# %% [markdown]
# ### Load national from Census American Community Survey (ACS5)

# %%
# map url to var
us_acs5_url = "https://api.census.gov/data/2017/acs/acs5?get=NAME,B01001_001E&for=us:*"

# import data from url
us_acs5_raw = requests.get(us_acs5_url)

# data to json
us_acs5_json = us_acs5_raw.json()

# json to dataframe
us_pop = pd.DataFrame(us_acs5_json[1:], columns = us_acs5_json[0]).rename(columns = 
                                                        {"B01001_001E": "population",
                                                         "NAME": "country"}).drop(['us'], axis = 1)
# show table
us_pop
# Out:
#          country population
# 0  United States  321004407

# %% [markdown]
# # Join state population to state case table

# %%
# join the population to the state test/case table
combined_1 = pd.merge(states, states_pop[['state', 'state_abbr', 'population']]
                      , on = 'state_abbr', how = 'left')#.drop('state_abbr', 1)

# show first five rows
combined_1.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease     state population
# 0                      71.0    Alaska     738565
# 1                    2314.0   Alabama    4850771
# 2                     841.0  Arkansas    2977944
# 3                       0.0       NaN        NaN
# 4                    2088.0   Arizona    6809946

# %% [markdown]
# # Create ratios

# %%
# by state, change in total from one day to the next
combined_1['tests_since_prev_day'] = combined_1.groupby('state')['total'].diff(-1)

# by state, change in positive from one day to the next
combined_1['positives_since_prev_day'] = combined_1.groupby('state')['positive'].diff(-1)

# by state, change in positive from one day to the next
combined_1['negatives_since_prev_day'] = combined_1.groupby('state')['negative'].diff(-1)

# show table
combined_1.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease     state population  tests_since_prev_day  \
# 0                      71.0    Alaska     738565                  71.0
# 1                    2314.0   Alabama    4850771                2314.0
# 2                     841.0  Arkansas    2977944                 841.0
# 3                       0.0       NaN        NaN                   NaN
# 4                    2088.0   Arizona    6809946                2088.0
#
#    positives_since_prev_day  negatives_since_prev_day
# 0                       7.0                      64.0
# 1                     232.0                    2082.0
# 2                      51.0                     790.0
# 3                       NaN                       NaN
# 4                     272.0                    1816.0

# %%
# look at NY state
combined_1[combined_1['state'] == "New York"].head(10)
# Out:
#            date state_abbr  positive  negative  pending  \
# 37   2020-04-16         NY  222284.0  328295.0      NaN
# 93   2020-04-15         NY  213779.0  312233.0      NaN
# 149  2020-04-14         NY  202208.0  296935.0      NaN
# 205  2020-04-13         NY  195031.0  283326.0      NaN
# 261  2020-04-12         NY  188694.0  272907.0      NaN
# 317  2020-04-11         NY  180458.0  260522.0      NaN
# 373  2020-04-10         NY  170512.0  247373.0      NaN
# 429  2020-04-09         NY  159937.0  231612.0      NaN
# 485  2020-04-08         NY  149316.0  215837.0      NaN
# 541  2020-04-07         NY  138863.0  201195.0      NaN
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 37                 17735.0                 50450.0          5091.0
# 93                 18697.0                 46201.0          5225.0
# 149                18697.0                 46201.0          5225.0
# 205                18825.0                 42712.0          5156.0
# 261                18707.0                 42594.0          5198.0
# 317                18654.0                 40679.0          5009.0
# 373                18569.0                 38818.0          4908.0
# 429                18279.0                 36576.0          4925.0
# 485                18079.0                 34432.0          4593.0
# 541                17493.0                 32083.0          4593.0
#
#      inIcuCumulative  onVentilatorCurrently  onVentilatorCumulative  \
# 37               NaN                    NaN                     NaN
# 93               NaN                    NaN                     NaN
# 149              NaN                    NaN                     NaN
# 205              NaN                    NaN                     NaN
# 261              NaN                    NaN                     NaN
# 317              NaN                    NaN                     NaN
# 373              NaN                    NaN                     NaN
# 429              NaN                    NaN                     NaN
# 485              NaN                    NaN                     NaN
# 541              NaN                    NaN                     NaN
#
#      recovered                                      hash  \
# 37     23887.0  bd386393a80d22e8b4638b53c9a00a316b7c209a
# 93     23887.0  1345a6429c3718d790172d3c91f25184b1df3832
# 149    23887.0  af7e566432a9ff3be22212c6e53deadb87354a33
# 205    23887.0  286aa877043319eac31dd16ed268926cee8f6d4a
# 261    23887.0  c34e542369716ac96cf4d5c56a0b44894e6a356f
# 317    22025.0  361c16745f9be4bc650b0fa0ebaabc36edad3d47
# 373    20249.0  b9f6747819f23a6d4d2caddb7dab2b4568f829f4
# 429    18297.0  adcfe0b7d9f5faf78429b00c69af00833443c8ec
# 485    16353.0  36db5397b3f156232e908feab224b44a19364028
# 541    14590.0  15947b1c9ed54db71e224d5882c2e146b415b520
#
#                   dateChecked    death  hospitalized     total  \
# 37  2020-04-16 20:00:00+00:00  12192.0       50450.0  550579.0
# 93  2020-04-15 20:00:00+00:00  11586.0       46201.0  526012.0
# 149 2020-04-14 20:00:00+00:00  10834.0       46201.0  499143.0
# 205 2020-04-13 20:00:00+00:00  10056.0       42712.0  478357.0
# 261 2020-04-12 20:00:00+00:00   9385.0       42594.0  461601.0
# 317 2020-04-11 20:00:00+00:00   8627.0       40679.0  440980.0
# 373 2020-04-10 20:00:00+00:00   7844.0       38818.0  417885.0
# 429 2020-04-09 20:00:00+00:00   7067.0       36576.0  391549.0
# 485 2020-04-08 20:00:00+00:00   6268.0       34432.0  365153.0
# 541 2020-04-07 20:00:00+00:00   5489.0       32083.0  340058.0
#
#      totalTestResults    posNeg fips  deathIncrease  hospitalizedIncrease  \
# 37           550579.0  550579.0   36          606.0                4249.0
# 93           526012.0  526012.0   36          752.0                   0.0
# 149          499143.0  499143.0   36          778.0                3489.0
# 205          478357.0  478357.0   36          671.0                 118.0
# 261          461601.0  461601.0   36          758.0                1915.0
# 317          440980.0  440980.0   36          783.0                1861.0
# 373          417885.0  417885.0   36          777.0                2242.0
# 429          391549.0  391549.0   36          799.0                2144.0
# 485          365153.0  365153.0   36          779.0                2349.0
# 541          340058.0  340058.0   36          731.0                1880.0
#
#      negativeIncrease  positiveIncrease  totalTestResultsIncrease     state  \
# 37            16062.0            8505.0                   24567.0  New York
# 93            15298.0           11571.0                   26869.0  New York
# 149           13609.0            7177.0                   20786.0  New York
# 205           10419.0            6337.0                   16756.0  New York
# 261           12385.0            8236.0                   20621.0  New York
# 317           13149.0            9946.0                   23095.0  New York
# 373           15761.0           10575.0                   26336.0  New York
# 429           15775.0           10621.0                   26396.0  New York
# 485           14642.0           10453.0                   25095.0  New York
# 541           11073.0            8174.0                   19247.0  New York
#
#     population  tests_since_prev_day  positives_since_prev_day  \
# 37    19798228               24567.0                    8505.0
# 93    19798228               26869.0                   11571.0
# 149   19798228               20786.0                    7177.0
# 205   19798228               16756.0                    6337.0
# 261   19798228               20621.0                    8236.0
# 317   19798228               23095.0                    9946.0
# 373   19798228               26336.0                   10575.0
# 429   19798228               26396.0                   10621.0
# 485   19798228               25095.0                   10453.0
# 541   19798228               19247.0                    8174.0
#
#      negatives_since_prev_day
# 37                    16062.0
# 93                    15298.0
# 149                   13609.0
# 205                   10419.0
# 261                   12385.0
# 317                   13149.0
# 373                   15761.0
# 429                   15775.0
# 485                   14642.0
# 541                   11073.0

# %%
# show data types by column
combined_1.dtypes
# Out:
# date                                     object
# state_abbr                               object
# positive                                float64
# negative                                float64
# pending                                 float64
# hospitalizedCurrently                   float64
# hospitalizedCumulative                  float64
# inIcuCurrently                          float64
# inIcuCumulative                         float64
# onVentilatorCurrently                   float64
# onVentilatorCumulative                  float64
# recovered                               float64
# hash                                     object
# dateChecked                 datetime64[ns, UTC]
# death                                   float64
# hospitalized                            float64
# total                                   float64
# totalTestResults                        float64
# posNeg                                  float64
# fips                                     object
# deathIncrease                           float64
# hospitalizedIncrease                    float64
# negativeIncrease                        float64
# positiveIncrease                        float64
# totalTestResultsIncrease                float64
# state                                    object
# population                               object
# tests_since_prev_day                    float64
# positives_since_prev_day                float64
# negatives_since_prev_day                float64
# dtype: object

# %%
# change population from object to numeric
combined_1['population'] = pd.to_numeric(combined_1['population'])

# %%
# tests per capita
combined_1['total_tests_per_person'] = combined_1['total'] / combined_1['population']

# %%
# show first five rows
combined_1.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease     state  population  tests_since_prev_day  \
# 0                      71.0    Alaska    738565.0                  71.0
# 1                    2314.0   Alabama   4850771.0                2314.0
# 2                     841.0  Arkansas   2977944.0                 841.0
# 3                       0.0       NaN         NaN                   NaN
# 4                    2088.0   Arizona   6809946.0                2088.0
#
#    positives_since_prev_day  negatives_since_prev_day  total_tests_per_person
# 0                       7.0                      64.0                0.011827
# 1                     232.0                    2082.0                0.007502
# 2                      51.0                     790.0                0.007614
# 3                       NaN                       NaN                     NaN
# 4                     272.0                    1816.0                0.006960

# %%
# get today's date
today = datetime.today().strftime('%Y-%m-%d')
today
# Out:
# '2020-04-16'

# %%
# filter date to today and sort states by highest test per capita
combined_1[combined_1['date'].isin([today])].sort_values(by = "total_tests_per_person", ascending = False).head()
# Out:
#           date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 37  2020-04-16         NY  222284.0  328295.0      NaN                17735.0
# 20  2020-04-16         LA   22532.0  104054.0      NaN                 1914.0
# 43  2020-04-16         RI    3838.0   24226.0      NaN                  245.0
# 21  2020-04-16         MA   32181.0  108592.0      NaN                 3454.0
# 51  2020-04-16         VT     768.0   10739.0      NaN                   58.0
#
#     hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 37                 50450.0          5091.0              NaN
# 20                     NaN             NaN              NaN
# 43                   331.0            61.0              NaN
# 21                  2340.0           973.0              NaN
# 51                     NaN             NaN              NaN
#
#     onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 37                    NaN                     NaN    23887.0
# 20                  396.0                     NaN        NaN
# 43                   43.0                     NaN      182.0
# 21                    NaN                     NaN        NaN
# 51                    NaN                     NaN       15.0
#
#                                         hash               dateChecked  \
# 37  bd386393a80d22e8b4638b53c9a00a316b7c209a 2020-04-16 20:00:00+00:00
# 20  6ae3a5f7f0b1e1a5c00710d1a5571702dfbff14c 2020-04-16 20:00:00+00:00
# 43  bb544990f7c3e3da791f26108024f6657594c9c3 2020-04-16 20:00:00+00:00
# 21  ec48a236ea400ddb66cf39987ce618642a9150bc 2020-04-16 20:00:00+00:00
# 51  1ea60000d2e949646925602b03e1fd49dd2bfeef 2020-04-16 20:00:00+00:00
#
#       death  hospitalized     total  totalTestResults    posNeg fips  \
# 37  12192.0       50450.0  550579.0          550579.0  550579.0   36
# 20   1156.0           NaN  126586.0          126586.0  126586.0   22
# 43    105.0         331.0   28064.0           28064.0   28064.0   44
# 21   1245.0        2340.0  140773.0          140773.0  140773.0   25
# 51     35.0           NaN   11507.0           11507.0   11507.0   50
#
#     deathIncrease  hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 37          606.0                4249.0           16062.0            8505.0
# 20           53.0                   0.0            4077.0             581.0
# 43           18.0                   0.0            1858.0             309.0
# 21          137.0                   0.0            6487.0            2263.0
# 51            5.0                   0.0             417.0               9.0
#
#     totalTestResultsIncrease          state  population  tests_since_prev_day  \
# 37                   24567.0       New York  19798228.0               24567.0
# 20                    4658.0      Louisiana   4663461.0                4658.0
# 43                    2167.0   Rhode Island   1056138.0                2167.0
# 21                    8750.0  Massachusetts   6789319.0                8750.0
# 51                     426.0        Vermont    624636.0                 426.0
#
#     positives_since_prev_day  negatives_since_prev_day  total_tests_per_person
# 37                    8505.0                   16062.0                0.027810
# 20                     581.0                    4077.0                0.027144
# 43                     309.0                    1858.0                0.026572
# 21                    2263.0                    6487.0                0.020734
# 51                       9.0                     417.0                0.018422

# %%
# determine positive rate per tests
combined_1['positive_per_test'] = combined_1['positives_since_prev_day'] / combined_1['tests_since_prev_day']
combined_1.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash               dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180 2020-04-16 20:00:00+00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f 2020-04-16 20:00:00+00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e 2020-04-16 20:00:00+00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c 2020-04-16 20:00:00+00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a 2020-04-16 20:00:00+00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease     state  population  tests_since_prev_day  \
# 0                      71.0    Alaska    738565.0                  71.0
# 1                    2314.0   Alabama   4850771.0                2314.0
# 2                     841.0  Arkansas   2977944.0                 841.0
# 3                       0.0       NaN         NaN                   NaN
# 4                    2088.0   Arizona   6809946.0                2088.0
#
#    positives_since_prev_day  negatives_since_prev_day  total_tests_per_person  \
# 0                       7.0                      64.0                0.011827
# 1                     232.0                    2082.0                0.007502
# 2                      51.0                     790.0                0.007614
# 3                       NaN                       NaN                     NaN
# 4                     272.0                    1816.0                0.006960
#
#    positive_per_test
# 0           0.098592
# 1           0.100259
# 2           0.060642
# 3                NaN
# 4           0.130268

# %% [markdown]
# # Display a few select states

# %%
# look at NY over time
combined_1[combined_1['state'] == 'New York'].head(10)
# Out:
#            date state_abbr  positive  negative  pending  \
# 37   2020-04-16         NY  222284.0  328295.0      NaN
# 93   2020-04-15         NY  213779.0  312233.0      NaN
# 149  2020-04-14         NY  202208.0  296935.0      NaN
# 205  2020-04-13         NY  195031.0  283326.0      NaN
# 261  2020-04-12         NY  188694.0  272907.0      NaN
# 317  2020-04-11         NY  180458.0  260522.0      NaN
# 373  2020-04-10         NY  170512.0  247373.0      NaN
# 429  2020-04-09         NY  159937.0  231612.0      NaN
# 485  2020-04-08         NY  149316.0  215837.0      NaN
# 541  2020-04-07         NY  138863.0  201195.0      NaN
#
#      hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# 37                 17735.0                 50450.0          5091.0
# 93                 18697.0                 46201.0          5225.0
# 149                18697.0                 46201.0          5225.0
# 205                18825.0                 42712.0          5156.0
# 261                18707.0                 42594.0          5198.0
# 317                18654.0                 40679.0          5009.0
# 373                18569.0                 38818.0          4908.0
# 429                18279.0                 36576.0          4925.0
# 485                18079.0                 34432.0          4593.0
# 541                17493.0                 32083.0          4593.0
#
#      inIcuCumulative  onVentilatorCurrently  onVentilatorCumulative  \
# 37               NaN                    NaN                     NaN
# 93               NaN                    NaN                     NaN
# 149              NaN                    NaN                     NaN
# 205              NaN                    NaN                     NaN
# 261              NaN                    NaN                     NaN
# 317              NaN                    NaN                     NaN
# 373              NaN                    NaN                     NaN
# 429              NaN                    NaN                     NaN
# 485              NaN                    NaN                     NaN
# 541              NaN                    NaN                     NaN
#
#      recovered                                      hash  \
# 37     23887.0  bd386393a80d22e8b4638b53c9a00a316b7c209a
# 93     23887.0  1345a6429c3718d790172d3c91f25184b1df3832
# 149    23887.0  af7e566432a9ff3be22212c6e53deadb87354a33
# 205    23887.0  286aa877043319eac31dd16ed268926cee8f6d4a
# 261    23887.0  c34e542369716ac96cf4d5c56a0b44894e6a356f
# 317    22025.0  361c16745f9be4bc650b0fa0ebaabc36edad3d47
# 373    20249.0  b9f6747819f23a6d4d2caddb7dab2b4568f829f4
# 429    18297.0  adcfe0b7d9f5faf78429b00c69af00833443c8ec
# 485    16353.0  36db5397b3f156232e908feab224b44a19364028
# 541    14590.0  15947b1c9ed54db71e224d5882c2e146b415b520
#
#                   dateChecked    death  hospitalized     total  \
# 37  2020-04-16 20:00:00+00:00  12192.0       50450.0  550579.0
# 93  2020-04-15 20:00:00+00:00  11586.0       46201.0  526012.0
# 149 2020-04-14 20:00:00+00:00  10834.0       46201.0  499143.0
# 205 2020-04-13 20:00:00+00:00  10056.0       42712.0  478357.0
# 261 2020-04-12 20:00:00+00:00   9385.0       42594.0  461601.0
# 317 2020-04-11 20:00:00+00:00   8627.0       40679.0  440980.0
# 373 2020-04-10 20:00:00+00:00   7844.0       38818.0  417885.0
# 429 2020-04-09 20:00:00+00:00   7067.0       36576.0  391549.0
# 485 2020-04-08 20:00:00+00:00   6268.0       34432.0  365153.0
# 541 2020-04-07 20:00:00+00:00   5489.0       32083.0  340058.0
#
#      totalTestResults    posNeg fips  deathIncrease  hospitalizedIncrease  \
# 37           550579.0  550579.0   36          606.0                4249.0
# 93           526012.0  526012.0   36          752.0                   0.0
# 149          499143.0  499143.0   36          778.0                3489.0
# 205          478357.0  478357.0   36          671.0                 118.0
# 261          461601.0  461601.0   36          758.0                1915.0
# 317          440980.0  440980.0   36          783.0                1861.0
# 373          417885.0  417885.0   36          777.0                2242.0
# 429          391549.0  391549.0   36          799.0                2144.0
# 485          365153.0  365153.0   36          779.0                2349.0
# 541          340058.0  340058.0   36          731.0                1880.0
#
#      negativeIncrease  positiveIncrease  totalTestResultsIncrease     state  \
# 37            16062.0            8505.0                   24567.0  New York
# 93            15298.0           11571.0                   26869.0  New York
# 149           13609.0            7177.0                   20786.0  New York
# 205           10419.0            6337.0                   16756.0  New York
# 261           12385.0            8236.0                   20621.0  New York
# 317           13149.0            9946.0                   23095.0  New York
# 373           15761.0           10575.0                   26336.0  New York
# 429           15775.0           10621.0                   26396.0  New York
# 485           14642.0           10453.0                   25095.0  New York
# 541           11073.0            8174.0                   19247.0  New York
#
#      population  tests_since_prev_day  positives_since_prev_day  \
# 37   19798228.0               24567.0                    8505.0
# 93   19798228.0               26869.0                   11571.0
# 149  19798228.0               20786.0                    7177.0
# 205  19798228.0               16756.0                    6337.0
# 261  19798228.0               20621.0                    8236.0
# 317  19798228.0               23095.0                    9946.0
# 373  19798228.0               26336.0                   10575.0
# 429  19798228.0               26396.0                   10621.0
# 485  19798228.0               25095.0                   10453.0
# 541  19798228.0               19247.0                    8174.0
#
#      negatives_since_prev_day  total_tests_per_person  positive_per_test
# 37                    16062.0                0.027810           0.346196
# 93                    15298.0                0.026569           0.430645
# 149                   13609.0                0.025211           0.345280
# 205                   10419.0                0.024162           0.378193
# 261                   12385.0                0.023315           0.399399
# 317                   13149.0                0.022274           0.430656
# 373                   15761.0                0.021107           0.401542
# 429                   15775.0                0.019777           0.402372
# 485                   14642.0                0.018444           0.416537
# 541                   11073.0                0.017176           0.424690

# %%
# look at NY over time
#combined_1[combined_1['state'] == 'New Jersey']

# %%
# look at WA over time
#combined_1[combined_1['state'] == 'Washington']

# %%
# look at VA over time
#combined_1[combined_1['state'] == 'Virginia']

# %%
# look at MD over time
#combined_1[combined_1['state'] == 'Maryland']

# %%
# look at DC over time
#combined_1[combined_1['state'] == 'District of Columbia']

# %%
# look at LA over time
#combined_1[combined_1['state'] == 'Louisiana']

# %% [markdown]
# # Finalize US National Data

# %%
# dislay us pop
us_pop
# Out:
#          country population
# 0  United States  321004407

# %%
# display first five rows of national dataset
national.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200416      56    663260  2737804.0  16927.0                57494.0
# 1  20200415      56    632656  2610099.0  16901.0                58361.0
# 2  20200414      56    602473  2479147.0  16615.0                54215.0
# 3  20200413      56    576774  2358232.0  17159.0                50968.0
# 4  20200412      56    551826  2254066.0  16419.0                51413.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 74705.0         15150.0           1834.0
# 1                 69603.0         14667.0           1783.0
# 2                 67547.0         14039.0           1715.0
# 3                 62673.0         13632.0           1628.0
# 4                 61201.0         13917.0           1455.0
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                 5940.0                   137.0    42032.0
# 1                 6032.0                   223.0    39405.0
# 2                 5975.0                   221.0    37645.0
# 3                 6168.0                   210.0    35442.0
# 4                 5986.0                   160.0    34151.0
#
#                                        hash           dateChecked  death  \
# 0  e42dcecd56cc690f4b4c5c242e02b8eb8e3491b6  2020-04-16T20:00:00Z  30296
# 1  ca6d549a02f56add12897c5a47d051c50f2e8c75  2020-04-15T20:00:00Z  28160
# 2  7ea156ba5cb34498d2798ce71d9470bdbb27201b  2020-04-14T20:00:00Z  25668
# 3  171a7aa78e00daf2ddb2e32baedcdf1127162a17  2020-04-13T20:00:00Z  23369
# 4  b66df37c6be1e91d8fb155d5612a9fb3202e8e52  2020-04-12T20:00:00Z  21919
#
#    hospitalized    total  totalTestResults   posNeg  deathIncrease  \
# 0       74705.0  3417991           3401064  3401064         2136.0
# 1       69603.0  3259656           3242755  3242755         2492.0
# 2       67547.0  3098235           3081620  3081620         2299.0
# 3       62673.0  2952165           2935006  2935006         1450.0
# 4       61201.0  2822311           2805892  2805892         1564.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                5102.0          127705.0           30604.0
# 1                2056.0          130952.0           30183.0
# 2                4874.0          120915.0           25699.0
# 3                1472.0          104166.0           24948.0
# 4                2652.0          111243.0           28983.0
#
#    totalTestResultsIncrease
# 0                  158309.0
# 1                  161135.0
# 2                  146614.0
# 3                  129114.0
# 4                  140226.0

# %%
# concat national dataset with the population
# code below duplicates us_pop by number of rows in national dataset to avoid NAs
national_final = pd.concat([national, 
                            pd.concat([us_pop.drop(['country'],
                                                   axis = 1)]*len(national), ignore_index = True)],
                           axis = 1)

# show first five rows
national_final.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20200416      56    663260  2737804.0  16927.0                57494.0
# 1  20200415      56    632656  2610099.0  16901.0                58361.0
# 2  20200414      56    602473  2479147.0  16615.0                54215.0
# 3  20200413      56    576774  2358232.0  17159.0                50968.0
# 4  20200412      56    551826  2254066.0  16419.0                51413.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                 74705.0         15150.0           1834.0
# 1                 69603.0         14667.0           1783.0
# 2                 67547.0         14039.0           1715.0
# 3                 62673.0         13632.0           1628.0
# 4                 61201.0         13917.0           1455.0
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                 5940.0                   137.0    42032.0
# 1                 6032.0                   223.0    39405.0
# 2                 5975.0                   221.0    37645.0
# 3                 6168.0                   210.0    35442.0
# 4                 5986.0                   160.0    34151.0
#
#                                        hash           dateChecked  death  \
# 0  e42dcecd56cc690f4b4c5c242e02b8eb8e3491b6  2020-04-16T20:00:00Z  30296
# 1  ca6d549a02f56add12897c5a47d051c50f2e8c75  2020-04-15T20:00:00Z  28160
# 2  7ea156ba5cb34498d2798ce71d9470bdbb27201b  2020-04-14T20:00:00Z  25668
# 3  171a7aa78e00daf2ddb2e32baedcdf1127162a17  2020-04-13T20:00:00Z  23369
# 4  b66df37c6be1e91d8fb155d5612a9fb3202e8e52  2020-04-12T20:00:00Z  21919
#
#    hospitalized    total  totalTestResults   posNeg  deathIncrease  \
# 0       74705.0  3417991           3401064  3401064         2136.0
# 1       69603.0  3259656           3242755  3242755         2492.0
# 2       67547.0  3098235           3081620  3081620         2299.0
# 3       62673.0  2952165           2935006  2935006         1450.0
# 4       61201.0  2822311           2805892  2805892         1564.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                5102.0          127705.0           30604.0
# 1                2056.0          130952.0           30183.0
# 2                4874.0          120915.0           25699.0
# 3                1472.0          104166.0           24948.0
# 4                2652.0          111243.0           28983.0
#
#    totalTestResultsIncrease population
# 0                  158309.0  321004407
# 1                  161135.0  321004407
# 2                  146614.0  321004407
# 3                  129114.0  321004407
# 4                  140226.0  321004407

# %%
national_final[:1].stack().reset_index()
# Out:
#     level_0                   level_1  \
# 0         0                      date
# 1         0                    states
# 2         0                  positive
# 3         0                  negative
# 4         0                   pending
# 5         0     hospitalizedCurrently
# 6         0    hospitalizedCumulative
# 7         0            inIcuCurrently
# 8         0           inIcuCumulative
# 9         0     onVentilatorCurrently
# 10        0    onVentilatorCumulative
# 11        0                 recovered
# 12        0                      hash
# 13        0               dateChecked
# 14        0                     death
# 15        0              hospitalized
# 16        0                     total
# 17        0          totalTestResults
# 18        0                    posNeg
# 19        0             deathIncrease
# 20        0      hospitalizedIncrease
# 21        0          negativeIncrease
# 22        0          positiveIncrease
# 23        0  totalTestResultsIncrease
# 24        0                population
#
#                                            0
# 0                                   20200416
# 1                                         56
# 2                                     663260
# 3                                 2.7378e+06
# 4                                      16927
# 5                                      57494
# 6                                      74705
# 7                                      15150
# 8                                       1834
# 9                                       5940
# 10                                       137
# 11                                     42032
# 12  e42dcecd56cc690f4b4c5c242e02b8eb8e3491b6
# 13                      2020-04-16T20:00:00Z
# 14                                     30296
# 15                                     74705
# 16                                   3417991
# 17                                   3401064
# 18                                   3401064
# 19                                      2136
# 20                                      5102
# 21                                    127705
# 22                                     30604
# 23                                    158309
# 24                                 321004407

# %% [markdown]
# # Write to Excel

# %%
# running code below since excel does not support datetimes with timezones
combined_1['dateChecked'] = combined_1['dateChecked'].dt.strftime('%Y-%m-%d %H:%M:%S')

# show first five rows
combined_1.head()
# Out:
#          date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 0  2020-04-16         AK     300.0    8435.0      NaN                    NaN
# 1  2020-04-16         AL    4345.0   32046.0      NaN                    NaN
# 2  2020-04-16         AR    1620.0   21055.0      NaN                   85.0
# 3  2020-04-16         AS       0.0       3.0     17.0                    NaN
# 4  2020-04-16         AZ    4234.0   43164.0      NaN                  578.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                    35.0             NaN              NaN
# 1                   553.0             NaN            227.0
# 2                     NaN             NaN              NaN
# 3                     NaN             NaN              NaN
# 4                     NaN           278.0              NaN
#
#    onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 0                    NaN                     NaN      110.0
# 1                    NaN                   137.0        NaN
# 2                   21.0                     NaN      548.0
# 3                    NaN                     NaN        NaN
# 4                  188.0                     NaN      460.0
#
#                                        hash          dateChecked  death  \
# 0  42353f78693987154276c7c482342a46ec11c180  2020-04-16 20:00:00    9.0
# 1  bc8d87a6ade709e9ed0c8824e73dff454277a85f  2020-04-16 20:00:00  133.0
# 2  95e15a426548163accca607e39e7c97a7e229f6e  2020-04-16 20:00:00   37.0
# 3  614a57a963d84c55c40b863aaf08221f68f0387c  2020-04-16 20:00:00    NaN
# 4  1a168d4509dfc562564670fbcf91399c32b0981a  2020-04-16 20:00:00  150.0
#
#    hospitalized    total  totalTestResults   posNeg fips  deathIncrease  \
# 0          35.0   8735.0            8735.0   8735.0   02            0.0
# 1         553.0  36391.0           36391.0  36391.0   01           12.0
# 2           NaN  22675.0           22675.0  22675.0   05            4.0
# 3           NaN     20.0               3.0      3.0   60            0.0
# 4           NaN  47398.0           47398.0  47398.0   04            8.0
#
#    hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 0                   1.0              64.0               7.0
# 1                  28.0            2082.0             232.0
# 2                   0.0             790.0              51.0
# 3                   0.0               0.0               0.0
# 4                   0.0            1816.0             272.0
#
#    totalTestResultsIncrease     state  population  tests_since_prev_day  \
# 0                      71.0    Alaska    738565.0                  71.0
# 1                    2314.0   Alabama   4850771.0                2314.0
# 2                     841.0  Arkansas   2977944.0                 841.0
# 3                       0.0       NaN         NaN                   NaN
# 4                    2088.0   Arizona   6809946.0                2088.0
#
#    positives_since_prev_day  negatives_since_prev_day  total_tests_per_person  \
# 0                       7.0                      64.0                0.011827
# 1                     232.0                    2082.0                0.007502
# 2                      51.0                     790.0                0.007614
# 3                       NaN                       NaN                     NaN
# 4                     272.0                    1816.0                0.006960
#
#    positive_per_test
# 0           0.098592
# 1           0.100259
# 2           0.060642
# 3                NaN
# 4           0.130268

# %%
# separate the most recent day into its own tab
#today = '2020-04-03'
most_recent_day = combined_1[combined_1['date'].isin([today])]
most_recent_day[most_recent_day.state_abbr.isin(['NY', 'NJ', 'DC'])]
# Out:
#           date state_abbr  positive  negative  pending  hospitalizedCurrently  \
# 8   2020-04-16         DC    2350.0    9800.0      NaN                  313.0
# 34  2020-04-16         NJ   75317.0   76513.0      NaN                 8224.0
# 37  2020-04-16         NY  222284.0  328295.0      NaN                17735.0
#
#     hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 8                      NaN           105.0              NaN
# 34                     NaN          2014.0              NaN
# 37                 50450.0          5091.0              NaN
#
#     onVentilatorCurrently  onVentilatorCumulative  recovered  \
# 8                    79.0                     NaN      552.0
# 34                 1645.0                     NaN        NaN
# 37                    NaN                     NaN    23887.0
#
#                                         hash          dateChecked    death  \
# 8   100abd89bf88d9f88b0684c7fd04cc5c47fdbb60  2020-04-16 20:00:00     81.0
# 34  8f04a2a6fb4ff0d2e41da80b7bca3da6ae2279ff  2020-04-16 20:00:00   3518.0
# 37  bd386393a80d22e8b4638b53c9a00a316b7c209a  2020-04-16 20:00:00  12192.0
#
#     hospitalized     total  totalTestResults    posNeg fips  deathIncrease  \
# 8            NaN   12150.0           12150.0   12150.0   11            9.0
# 34           NaN  151830.0          151830.0  151830.0   34          362.0
# 37       50450.0  550579.0          550579.0  550579.0   36          606.0
#
#     hospitalizedIncrease  negativeIncrease  positiveIncrease  \
# 8                    0.0             472.0             153.0
# 34                   0.0            3522.0            4287.0
# 37                4249.0           16062.0            8505.0
#
#     totalTestResultsIncrease                 state  population  \
# 8                      625.0  District of Columbia    672391.0
# 34                    7809.0            New Jersey   8960161.0
# 37                   24567.0              New York  19798228.0
#
#     tests_since_prev_day  positives_since_prev_day  negatives_since_prev_day  \
# 8                  625.0                     153.0                     472.0
# 34                7809.0                    4287.0                    3522.0
# 37               24567.0                    8505.0                   16062.0
#
#     total_tests_per_person  positive_per_test
# 8                 0.018070           0.244800
# 34                0.016945           0.548982
# 37                0.027810           0.346196

# %%
# to excel
with pd.ExcelWriter('../outputs/States_Daily_4PM.xlsx') as writer:
    combined_1.to_excel(writer, sheet_name = 'States Daily 4PM', index = False)
    most_recent_day.to_excel(writer, sheet_name = 'Most Recent Day', index = False)
